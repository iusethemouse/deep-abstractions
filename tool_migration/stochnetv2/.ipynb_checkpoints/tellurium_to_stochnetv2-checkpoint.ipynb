# %% [markdown]
# # Using Tellurium-generated dataset as input for StochNetV2

# %% [markdown]
# We replace the `build_simulation_dataset` utility of StochNetV2 with a custom Tellurium-based dataset generation utility.

# %%
import tellurium as te
import numpy as np
import pandas as pd

from importlib import import_module
from pathlib import Path
import json

from stochnet_v2.utils.file_organisation import ProjectFileExplorer
from stochnet_v2.dataset.simulation_gillespy import build_simulation_dataset
from stochnet_v2.dataset.dataset import DataTransformer
from stochnet_v2.static_classes.trainer import ToleranceDropLearningStrategy
from stochnet_v2.dynamic_classes.model import StochNet
from stochnet_v2.static_classes.trainer import Trainer

# %% [markdown]
# ## Tellurium dataset generator

# %%
class TeDatasetGenerator:
    
    def __init__(
        self,
        filename="example.xml",
        n_initial_settings=10,
        n_simulations_per_setting=10,
        steps=11,
        endtime=1.0
    ):
        self.filename = filename
        self.n_initial_settings = n_initial_settings
        self.n_simulations_per_setting = n_simulations_per_setting
        self.steps = steps
        self.endtime = endtime
        
        self.model = self.set_up_model()
        self.init_concentrations = self.randomize_species_concentrations()
        self.randomized_parameters = self.randomize_parameters()
        self.variable_names = self.get_variable_names()
        
    def simulate(self):
        results = []
        for init_setting in range(self.n_initial_settings):
            for sim_iteration in range(self.n_simulations_per_setting):
                self.model.reset()
                self.assign_custom_values_to_model(self.init_concentrations[init_setting])
                self.assign_custom_values_to_model(self.randomized_parameters[init_setting])
                sim = self.model.simulate(0.0, self.endtime, self.steps)

                # Add the randomized parameters as new columns
                for param_name, param_value in self.randomized_parameters[init_setting].items():
                    param_column = np.full((sim.shape[0], 1), param_value)
                    sim = np.hstack((sim, param_column))

                results.append(sim)

        return np.concatenate([np.expand_dims(a, axis=0) for a in results], axis=0)
        
        
    def set_up_model(self):
        model = te.loads(self.filename)
        model.integrator = "gillespie"
        model.integrator.seed = 42
        
        return model
    
    
    def randomize_species_concentrations(self):
        """
        Returns: list of n dictionaries, where keys are species.
        """
        species_names = self.model.getFloatingSpeciesConcentrationIds()
        species_values = self.model.getFloatingSpeciesConcentrations()

        random_concentrations = []
        for _ in range(self.n_initial_settings):
            iteration_concentrations = {}

            for name, value in zip(species_names, species_values):
                low = max(0, int(value / 2))
                high = int(value * 2)
                iteration_concentrations[name] = float(np.random.randint(low, high))

            random_concentrations.append(iteration_concentrations)

        return random_concentrations
    
        
    def randomize_parameters(self, sigma=0.1):
        """
        Returns: list of n dictionaries, where keys are parameters.
        """
        parameter_names = self.model.getGlobalParameterIds()
        parameter_values = self.model.getGlobalParameterValues()

        random_parameters = []
        num_parameters = len(parameter_names)

        for i in range(self.n_initial_settings):
            iteration_parameters = {}

            for j, (name, value) in enumerate(zip(parameter_names, parameter_values)):
                if i % num_parameters == j:
                    shift = np.random.uniform(-sigma, sigma) * value
                    iteration_parameters[name] = value + shift
                else:
                    # keep the default value for other parameters
                    iteration_parameters[name] = value

            random_parameters.append(iteration_parameters)

        return random_parameters


    def assign_custom_values_to_model(self, value_dict):
        """
        value_dict: can be species concentrations, parameters values, etc.
        Returns: the model with assigned values.
        """
        for prop_name, prop_value in value_dict.items():
            self.model[prop_name] = prop_value


    def get_variable_names(self):
        names = ["time"]
        names.extend(self.model.getFloatingSpeciesConcentrationIds())
        names.extend(self.model.getGlobalParameterIds())

        return names
    
    def get_initial_concentrations_array(self):
        return np.array([list(d.values()) for d in self.init_concentrations])
    
    def get_randomized_params_dict(self):
        params = {}
        for d in self.randomized_parameters:
            for k, v in d.items():
                if k not in params:
                    params[k] = []
                params[k].append(v)
        return params

    def get_merged_concentrations_and_params(self):
        keys = list(self.randomized_parameters[0].keys())
        new_rows = []
        
        for param_dict, row in zip(self.randomized_parameters, self.get_initial_concentrations_array()):
            new_row = np.append(row, [param_dict[key] for key in keys])
            new_rows.append(new_row)

        new_concentrations = np.array(new_rows)

        return new_concentrations

# %% [markdown]
# ## Dataset generation and transformation

# %%
name = "SIR"
timestep = 0.1
endtime = 10.0
n_initial_settings = 100
n_simulations_per_setting = 10

params = ["gamma", "beta"]

model_name = name
dataset_id = name
model_id = name

# %%
project_folder = Path("").parent.resolve() / model_name
project_explorer = ProjectFileExplorer(project_folder)
dataset_explorer = project_explorer.get_dataset_file_explorer(timestep, dataset_id)
model_explorer = project_explorer.get_model_file_explorer(timestep, model_id)

# %% [markdown]
# ### Generate initial settings

# %%
# SN settings generation using custom network definition via GillesPy2
CRN_module = import_module(model_name)
CRN_class = getattr(CRN_module, model_name)

settings = CRN_class.get_initial_settings(n_initial_settings)
print(settings)
# Out:
# [[ 99. 196.  48.]
#  [ 53. 155.  66.]
#  [ 87. 142.  79.]
#  [121. 150.  98.]
#  [144.  98. 187.]
#  [ 81. 144. 108.]
#  [137. 157. 180.]
#  [ 56. 161.  72.]
#  [104.  80.  72.]
#  [161.  84. 139.]]

# %%
# Tellurium settings generation
te_gen = TeDatasetGenerator(
    n_initial_settings=100,
    n_simulations_per_setting=10,
    steps=11,
    endtime=10.0
)
te_settings = te_gen.get_initial_concentrations_array()
print(te_settings)
# Out:
# [[ 73. 131. 125.]
#  [152. 188. 105.]
#  [155.  71. 173.]
#  [ 97. 116. 134.]
#  [ 56. 189.  61.]
#  [ 60. 199. 114.]
#  [121. 159.  82.]
#  [103.  51.  96.]
#  [134. 191.  69.]
#  [182. 127. 124.]
#  [155. 171. 174.]
#  [ 51. 161. 155.]
#  [ 57. 120.  72.]
#  [146. 163. 154.]
#  [184. 152. 141.]
#  [ 75. 190.  82.]
#  [172.  65.  59.]
#  [170.  62. 114.]
#  [ 54. 182. 180.]
#  [186. 107.  69.]
#  [130. 128. 107.]
#  [ 92.  91. 191.]
#  [116. 194.  54.]
#  [161. 178. 127.]
#  [115. 140. 146.]
#  [110. 197. 108.]
#  [195.  71. 139.]
#  [188. 174.  62.]
#  [113.  97. 195.]
#  [ 81. 102. 143.]
#  [107.  67.  67.]
#  [ 91.  96. 146.]
#  [181. 187.  93.]
#  [ 68. 178. 183.]
#  [191. 102. 138.]
#  [ 64. 112.  99.]
#  [138.  69.  62.]
#  [133. 179. 123.]
#  [ 76.  83.  96.]
#  [145. 142. 124.]
#  [157. 175. 192.]
#  [ 74. 163.  69.]
#  [132. 189. 187.]
#  [ 61. 175.  88.]
#  [146.  68.  55.]
#  [193. 174. 116.]
#  [142. 125.  64.]
#  [ 78.  87. 163.]
#  [118. 129. 128.]
#  [176. 142. 132.]
#  [ 54. 174.  91.]
#  [171. 106. 193.]
#  [ 79. 168. 164.]
#  [164. 173.  66.]
#  [144. 114. 122.]
#  [169. 137. 189.]
#  [181. 169. 160.]
#  [123.  57.  98.]
#  [163. 110. 125.]
#  [161. 190.  55.]
#  [ 68. 146.  57.]
#  [ 57. 197. 191.]
#  [ 68. 168.  69.]
#  [135. 126. 197.]
#  [167. 126. 146.]
#  [ 83. 122.  91.]
#  [179. 114. 171.]
#  [165. 138.  55.]
#  [142. 199.  87.]
#  [165. 134.  50.]
#  [188.  75. 189.]
#  [154. 155. 180.]
#  [ 77. 144. 134.]
#  [171. 118. 153.]
#  [143.  92.  88.]
#  [105. 191. 161.]
#  [ 84. 105. 190.]
#  [102. 195.  64.]
#  [ 98. 114.  54.]
#  [ 53. 111. 191.]
#  [173. 163. 109.]
#  [100. 189. 164.]
#  [ 79. 134.  95.]
#  [ 57. 197. 125.]
#  [ 76.  52. 126.]
#  [162. 155. 159.]
#  [149. 141.  65.]
#  [ 69. 105.  82.]
#  [182. 133.  71.]
#  [187. 199. 114.]
#  [190.  84. 132.]
#  [ 71.  58. 169.]
#  [142.  99. 175.]
#  [ 77. 142. 184.]
#  [171. 182. 184.]
#  [ 88. 125.  52.]
#  [140.  72. 128.]
#  [ 89. 131.  65.]
#  [192. 124. 195.]
#  [175. 160.  98.]]

# %%
# save the Tellurium-generated settings
np.save(dataset_explorer.settings_fp, te_settings)

# %% [markdown]
# ### Generate dataset

# %%
# SN dataset generation
dataset = build_simulation_dataset(
    model_name,
    n_initial_settings,
    n_simulations_per_setting,
    timestep,
    endtime,
    dataset_explorer.dataset_folder,
    params_to_randomize=params,
)
# Out:
# 2023-07-08 12:22:02,931 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:02,932 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:04,701 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:04,703 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:06,474 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:06,476 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:08,229 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:08,230 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:10,005 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:10,006 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:11,762 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:11,763 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:13,519 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:13,520 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:15,268 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:15,270 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:17,030 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:17,032 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:18,793 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 2023-07-08 12:22:18,794 - GillesPy2 - WARNING -
#             Model.set_parameter has been deprecated.  Future releases of GillesPy2 may
#             not support this feature.  Parameter.expression should only be set in the constructor.
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 3064.67it/s]

# %%
print(f"dataset shape: {dataset.shape}\n")
print(f"first simulation:\n{dataset[0]}")
# Out:
# dataset shape: (100, 11, 6)
#
# first simulation:
# [[  0.          89.         186.          50.           1.01743801
#     3.        ]
#  [  0.1         88.         196.          41.           1.01743801
#     3.        ]
#  [  0.2         83.         204.          38.           1.01743801
#     3.        ]
#  [  0.3         75.         216.          34.           1.01743801
#     3.        ]
#  [  0.4         69.         223.          33.           1.01743801
#     3.        ]
#  [  0.5         71.         225.          29.           1.01743801
#     3.        ]
#  [  0.6         66.         232.          27.           1.01743801
#     3.        ]
#  [  0.7         59.         240.          26.           1.01743801
#     3.        ]
#  [  0.8         55.         246.          24.           1.01743801
#     3.        ]
#  [  0.9         52.         250.          23.           1.01743801
#     3.        ]
#  [  1.          48.         256.          21.           1.01743801
#     3.        ]]

# %%
# Tellurium dataset generation
te_dataset = te_gen.simulate()

# %%
print(f"tellurium dataset shape: {te_dataset.shape}\n")
print(f"first simulation:\n{te_dataset[0]}")
# Out:
# tellurium dataset shape: (1000, 11, 6)
#
# first simulation:
# [[  0.        73.       131.       125.         2.984349   1.      ]
#  [  1.        65.       197.        67.         2.984349   1.      ]
#  [  2.        35.       252.        42.         2.984349   1.      ]
#  [  3.        14.       278.        37.         2.984349   1.      ]
#  [  4.         5.       290.        34.         2.984349   1.      ]
#  [  5.         2.       294.        33.         2.984349   1.      ]
#  [  6.         0.       296.        33.         2.984349   1.      ]
#  [  7.         0.       296.        33.         2.984349   1.      ]
#  [  8.         0.       296.        33.         2.984349   1.      ]
#  [  9.         0.       296.        33.         2.984349   1.      ]
#  [ 10.         0.       296.        33.         2.984349   1.      ]]

# %%
# save the Tellurium-generated dataset
np.save(dataset_explorer.dataset_fp, te_dataset)

# %% [markdown]
# ### Dataset transformation and preparation for NN input

# %%
dt = DataTransformer(
    dataset_explorer.dataset_fp,
    with_timestamps=True,
    nb_randomized_params=len(params),
)

# %%
dt.save_data_for_ml_hdf5(
    dataset_folder=dataset_explorer.dataset_folder,
    nb_past_timesteps=1,
    test_fraction=0.2,
    keep_timestamps=False,
    rescale=True,
    positivity=False,
    shuffle=True,
    slice_size=100,
    force_rewrite=True,
)
# Out:
# dataset.dataset - INFO - Fitting scaler, positivity=False
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 1021.43it/s]
# dataset.dataset - INFO - Train data saved to /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/dataset/data/0.1/SIR/train_rescaled.hdf5,
# Shapes: x: (8000, 1, 5), y: (8000, 3)
# dataset.dataset - INFO - Test data saved to /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/dataset/data/0.1/SIR/test_rescaled.hdf5,
# Shapes: x: (2000, 1, 5), y: (2000, 3)

# %% [markdown]
# ## NN

# %% [markdown]
# ### Training

# %%
# NN Architecture Configuration
body_config_path = model_explorer.body_config_fp
mixture_config_path = model_explorer.mixture_config_fp

body_hidden_size = 30
body_n_blocks = 2
body_activation = "relu"
body_regularizer = "none"
body_kernel_constraint = "none"
body_bias_constraint = "none"
body_kernel_regularizer = "l2"
body_bias_regularizer = "l2"


components_hidden_size = "none"
n_normal_diag = 6
n_normal_tril = 0
n_log_normal_tril = 0
components_activation = "none"
components_regularizer = "none"
components_kernel_constraint = "none"
components_bias_constraint = "none"
components_kernel_regularizer = "l2"
components_bias_regularizer = "l2"

body_config = {
    "body_fn_name": "body_b",
    "block_name": "a",
    "hidden_size": body_hidden_size,
    "n_blocks": body_n_blocks,
    "use_batch_norm": False,
    "activation": body_activation,
    "activity_regularizer": body_regularizer,
    "kernel_constraint": body_kernel_constraint,
    "kernel_regularizer": body_kernel_regularizer,
    "bias_constraint": body_bias_constraint,
    "bias_regularizer": body_bias_regularizer,
}

categorical_config = {
    "hidden_size": components_hidden_size,
    "activation": components_activation,
    "coeff_regularizer": "none",
    "kernel_constraint": components_kernel_constraint,  # "maxnorm"
    "kernel_regularizer": components_kernel_regularizer,
    "bias_constraint": components_bias_constraint,  # "maxnorm"
    "bias_regularizer": components_bias_regularizer,
}

normal_diag_config = {
    "hidden_size": components_hidden_size,
    "activation": components_activation,
    "mu_regularizer": components_regularizer,
    "diag_regularizer": "l2",
    "kernel_constraint": components_kernel_constraint,
    "kernel_regularizer": components_kernel_regularizer,
    "bias_constraint": components_bias_constraint,
    "bias_regularizer": components_bias_regularizer,
}

normal_tril_config = {
    "hidden_size": components_hidden_size,
    "activation": components_activation,
    "mu_regularizer": components_regularizer,
    "diag_regularizer": components_regularizer,
    "sub_diag_regularizer": components_regularizer,
    "kernel_constraint": components_kernel_constraint,
    "kernel_regularizer": components_kernel_regularizer,
    "bias_constraint": components_bias_constraint,
    "bias_regularizer": components_bias_regularizer,
}

log_normal_tril_config = {
    "hidden_size": components_hidden_size,
    "activation": components_activation,
    "mu_regularizer": components_regularizer,
    "diag_regularizer": components_regularizer,
    "sub_diag_regularizer": components_regularizer,
    "kernel_constraint": components_kernel_constraint,
    "kernel_regularizer": components_kernel_regularizer,
    "bias_constraint": components_bias_constraint,
    "bias_regularizer": components_bias_regularizer,
}

# Write the configurations to disk
mixture_config = (
    [["categorical", categorical_config]]
    + [["normal_diag", normal_diag_config] for i in range(n_normal_diag)]
    + [["normal_tril", normal_tril_config] for i in range(n_normal_tril)]
    + [["log_normal_tril", log_normal_tril_config] for i in range(n_log_normal_tril)]
)

with open(body_config_path, "w+") as f:
    json.dump(body_config, f, indent="\t")

with open(mixture_config_path, "w+") as f:
    json.dump(mixture_config, f, indent="\t")

learning_strategy = ToleranceDropLearningStrategy(
    optimizer_type="adam",
    initial_lr=1e-4,
    lr_decay=0.3,
    epochs_tolerance=7,
    minimal_lr=1e-7,
)

# %%
# Training configuration
n_epochs = 100
batch_size = 256
add_noise = True
stddev = 0.01
dataset_kind = "hdf5"

# NN definition and training
nn = StochNet(
    nb_past_timesteps=1,
    nb_features=3,
    nb_randomized_params=len(params),
    project_folder=project_folder,
    timestep=timestep,
    dataset_id=dataset_id,
    model_id=model_id,
)

ckpt_path = None

ckpt_path = Trainer().train(
    nn,
    n_epochs=n_epochs,
    batch_size=batch_size,
    learning_strategy=learning_strategy,
    ckpt_path=ckpt_path,
    dataset_kind=dataset_kind,
    add_noise=add_noise,
    stddev=stddev,
)

with open("best_ckpt.txt", "w") as f:
    f.write(ckpt_path)
# Out:
# static_classes.nn_bodies - INFO -
#  ** Building 'body_b' body, hidden size: 30
#     with 2 of 'a' block
#     activation: relu
#     activity_regularizer: none
#     kernel_constraint: none
#     kernel_regularizer: l2
#     bias_constraint: none
#     bias_regularizer: l2
#     use BatchNorm: False
#  **
#
# static_classes.top_layers - DEBUG - Mixture components share nn outputs
# static_classes.top_layers - DEBUG - base shape: [None, 30]
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.top_layers - DEBUG - Using non-nnegative elu activation for diagonal
# static_classes.model - INFO - Model's graph keys saved at /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/models/0.1/SIR/graph_keys.json
# static_classes.model - INFO - Model created in normal mode.
# static_classes.trainer - DEBUG - REGULARIZATION_LOSSES:Tensor("total_regularization_loss:0", shape=(), dtype=float32)
# static_classes.trainer - INFO - Total number of trainable vars 36
# static_classes.trainer - INFO - Total number of optimizer vars 74
# static_classes.trainer - INFO - Training...
# static_classes.trainer - INFO -
# Epoch: 1
# static_classes.trainer - INFO -  = Minimal loss value = 15.299310684204102,
#  - 31 steps took 9.3 seconds, avg_step_time=0.300
#  - test time: 1.7 seconds
# static_classes.trainer - INFO -
# Epoch: 2
# static_classes.trainer - INFO -  = Minimal loss value = 13.149208068847656,
#  - 31 steps took 5.1 seconds, avg_step_time=0.163
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 3
# static_classes.trainer - INFO -  = Minimal loss value = 12.55609130859375,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 4
# static_classes.trainer - INFO -  = Minimal loss value = 11.722023963928223,
#  - 31 steps took 4.9 seconds, avg_step_time=0.159
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 5
# static_classes.trainer - INFO -  = Minimal loss value = 11.047825813293457,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 6
# static_classes.trainer - INFO -  = Minimal loss value = 10.824101448059082,
#  - 31 steps took 4.9 seconds, avg_step_time=0.157
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 7
# static_classes.trainer - INFO -  = Minimal loss value = 10.238243103027344,
#  - 31 steps took 4.9 seconds, avg_step_time=0.159
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 8
# static_classes.trainer - INFO -  = Minimal loss value = 9.869487762451172,
#  - 31 steps took 4.7 seconds, avg_step_time=0.152
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 9
# static_classes.trainer - INFO -  = Minimal loss value = 9.439613342285156,
#  - 31 steps took 5.6 seconds, avg_step_time=0.180
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 10
# static_classes.trainer - INFO -  = Minimal loss value = 9.015289306640625,
#  - 31 steps took 4.9 seconds, avg_step_time=0.157
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 11
# static_classes.trainer - INFO -  = Minimal loss value = 8.755476951599121,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 12
# static_classes.trainer - INFO -  = Minimal loss value = 8.300142288208008,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 13
# static_classes.trainer - INFO -  = Minimal loss value = 8.029929161071777,
#  - 31 steps took 4.9 seconds, avg_step_time=0.159
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 14
# static_classes.trainer - INFO -  = Minimal loss value = 7.858741760253906,
#  - 31 steps took 4.8 seconds, avg_step_time=0.156
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 15
# static_classes.trainer - INFO -  = Minimal loss value = 7.596535682678223,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 16
# static_classes.trainer - INFO -  = Minimal loss value = 7.343238830566406,
#  - 31 steps took 4.7 seconds, avg_step_time=0.153
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 17
# static_classes.trainer - INFO -  = Minimal loss value = 7.134324073791504,
#  - 31 steps took 5.0 seconds, avg_step_time=0.160
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 18
# static_classes.trainer - INFO -  = Minimal loss value = 6.940505027770996,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 19
# static_classes.trainer - INFO -  = Minimal loss value = 6.708498001098633,
#  - 31 steps took 5.0 seconds, avg_step_time=0.162
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 20
# static_classes.trainer - INFO -  = Minimal loss value = 6.524744987487793,
#  - 31 steps took 4.8 seconds, avg_step_time=0.156
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 21
# static_classes.trainer - INFO -  = Minimal loss value = 6.312825679779053,
#  - 31 steps took 4.9 seconds, avg_step_time=0.158
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 22
# static_classes.trainer - INFO -  = Minimal loss value = 6.087353706359863,
#  - 31 steps took 4.9 seconds, avg_step_time=0.159
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 23
# static_classes.trainer - INFO -  = Minimal loss value = 5.863033294677734,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 24
# static_classes.trainer - INFO -  = Minimal loss value = 5.649489402770996,
#  - 31 steps took 5.1 seconds, avg_step_time=0.163
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 25
# static_classes.trainer - INFO -  = Minimal loss value = 5.463722229003906,
#  - 31 steps took 4.9 seconds, avg_step_time=0.157
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 26
# static_classes.trainer - INFO -  = Minimal loss value = 5.081785678863525,
#  - 31 steps took 5.0 seconds, avg_step_time=0.162
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 27
# static_classes.trainer - INFO -  = Minimal loss value = 5.014681816101074,
#  - 31 steps took 4.9 seconds, avg_step_time=0.157
#  - test time: 1.0 seconds
# static_classes.trainer - INFO -
# Epoch: 28
# static_classes.trainer - INFO -  = Minimal loss value = 4.785913944244385,
#  - 31 steps took 5.0 seconds, avg_step_time=0.161
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 29
# static_classes.trainer - INFO -  = Minimal loss value = 4.479534149169922,
#  - 31 steps took 4.9 seconds, avg_step_time=0.157
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 30
# static_classes.trainer - INFO -  = Minimal loss value = 4.1828413009643555,
#  - 31 steps took 5.0 seconds, avg_step_time=0.160
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 31
# static_classes.trainer - INFO -  = Minimal loss value = 4.013132572174072,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 32
# static_classes.trainer - INFO -  = Minimal loss value = 3.7251837253570557,
#  - 31 steps took 5.0 seconds, avg_step_time=0.160
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 33
# static_classes.trainer - INFO -  = Minimal loss value = 3.376812219619751,
#  - 31 steps took 5.0 seconds, avg_step_time=0.161
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 34
# static_classes.trainer - INFO -  = Minimal loss value = 3.034545421600342,
#  - 31 steps took 5.2 seconds, avg_step_time=0.169
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 35
# static_classes.trainer - INFO -  = Minimal loss value = 2.7594637870788574,
#  - 31 steps took 5.0 seconds, avg_step_time=0.161
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 36
# static_classes.trainer - INFO -  = Minimal loss value = 2.416475296020508,
#  - 31 steps took 5.2 seconds, avg_step_time=0.167
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 37
# static_classes.trainer - INFO -  = Minimal loss value = 2.05922269821167,
#  - 31 steps took 5.3 seconds, avg_step_time=0.170
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 38
# static_classes.trainer - INFO -  = Minimal loss value = 1.7058104276657104,
#  - 31 steps took 5.3 seconds, avg_step_time=0.171
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 39
# static_classes.trainer - INFO -  = Minimal loss value = 1.2477200031280518,
#  - 31 steps took 5.3 seconds, avg_step_time=0.172
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 40
# static_classes.trainer - INFO -  = Minimal loss value = 0.9137452840805054,
#  - 31 steps took 5.2 seconds, avg_step_time=0.168
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 41
# static_classes.trainer - INFO -  = Minimal loss value = 0.33874255418777466,
#  - 31 steps took 5.4 seconds, avg_step_time=0.173
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 42
# static_classes.trainer - INFO -  = Minimal loss value = 0.03797072917222977,
#  - 31 steps took 5.0 seconds, avg_step_time=0.162
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 43
# static_classes.trainer - INFO -  = Minimal loss value = -0.31689196825027466,
#  - 31 steps took 4.9 seconds, avg_step_time=0.158
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 44
# static_classes.trainer - INFO -  = Minimal loss value = -0.781734049320221,
#  - 31 steps took 5.0 seconds, avg_step_time=0.163
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 45
# static_classes.trainer - INFO -  = Minimal loss value = -1.051496148109436,
#  - 31 steps took 5.0 seconds, avg_step_time=0.162
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 46
# static_classes.trainer - INFO -  = Minimal loss value = -1.3338115215301514,
#  - 31 steps took 5.0 seconds, avg_step_time=0.160
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 47
# static_classes.trainer - INFO -  = Minimal loss value = -1.7083109617233276,
#  - 31 steps took 4.9 seconds, avg_step_time=0.158
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 48
# static_classes.trainer - INFO -  = Minimal loss value = -2.0257785320281982,
#  - 31 steps took 5.0 seconds, avg_step_time=0.161
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 49
# static_classes.trainer - INFO -  = Minimal loss value = -2.2583093643188477,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 50
# static_classes.trainer - INFO -  = Minimal loss value = -2.4144606590270996,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 51
# static_classes.trainer - INFO -  = Minimal loss value = -2.779010772705078,
#  - 31 steps took 5.0 seconds, avg_step_time=0.160
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 52
# static_classes.trainer - INFO -  = Minimal loss value = -2.9361987113952637,
#  - 31 steps took 5.0 seconds, avg_step_time=0.161
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 53
# static_classes.trainer - INFO -  = Minimal loss value = -3.3132996559143066,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 54
# static_classes.trainer - INFO -  = Minimal loss value = -3.412729263305664,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 55
# static_classes.trainer - INFO -  = Minimal loss value = -3.6435346603393555,
#  - 31 steps took 4.5 seconds, avg_step_time=0.145
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 56
# static_classes.trainer - INFO -  = Minimal loss value = -3.7387733459472656,
#  - 31 steps took 4.7 seconds, avg_step_time=0.150
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 57
# static_classes.trainer - INFO -  = Minimal loss value = -3.901183843612671,
#  - 31 steps took 4.7 seconds, avg_step_time=0.150
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 58
# static_classes.trainer - INFO -  = Minimal loss value = -4.034847259521484,
#  - 31 steps took 4.7 seconds, avg_step_time=0.152
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 59
# static_classes.trainer - INFO -  = Minimal loss value = -4.236454963684082,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 60
# static_classes.trainer - INFO -  = Minimal loss value = -4.5089006423950195,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 61
# static_classes.trainer - INFO -  = Minimal loss value = -4.535818099975586,
#  - 31 steps took 4.6 seconds, avg_step_time=0.149
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 62
# static_classes.trainer - INFO -  = Minimal loss value = -4.585713863372803,
#  - 31 steps took 4.6 seconds, avg_step_time=0.149
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 63
# static_classes.trainer - INFO -  = Minimal loss value = -4.794642448425293,
#  - 31 steps took 4.9 seconds, avg_step_time=0.158
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 64
# static_classes.trainer - INFO -  = Minimal loss value = -4.919535160064697,
#  - 31 steps took 5.0 seconds, avg_step_time=0.162
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 65
# static_classes.trainer - INFO -  = Minimal loss value = -4.9672651290893555,
#  - 31 steps took 4.8 seconds, avg_step_time=0.156
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 66
# static_classes.trainer - INFO -  = Minimal loss value = -4.9672651290893555,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 67
# static_classes.trainer - INFO -  = Minimal loss value = -5.032306671142578,
#  - 31 steps took 5.2 seconds, avg_step_time=0.167
#  - test time: 1.0 seconds
# static_classes.trainer - INFO -
# Epoch: 68
# static_classes.trainer - INFO -  = Minimal loss value = -5.17493200302124,
#  - 31 steps took 5.1 seconds, avg_step_time=0.166
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 69
# static_classes.trainer - INFO -  = Minimal loss value = -5.271275520324707,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 70
# static_classes.trainer - INFO -  = Minimal loss value = -5.364350318908691,
#  - 31 steps took 4.8 seconds, avg_step_time=0.154
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 71
# static_classes.trainer - INFO -  = Minimal loss value = -5.4964094161987305,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 72
# static_classes.trainer - INFO -  = Minimal loss value = -5.4964094161987305,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 73
# static_classes.trainer - INFO -  = Minimal loss value = -5.502285480499268,
#  - 31 steps took 4.7 seconds, avg_step_time=0.152
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 74
# static_classes.trainer - INFO -  = Minimal loss value = -5.6491804122924805,
#  - 31 steps took 4.6 seconds, avg_step_time=0.149
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 75
# static_classes.trainer - INFO -  = Minimal loss value = -5.6491804122924805,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 1.0 seconds
# static_classes.trainer - INFO -
# Epoch: 76
# static_classes.trainer - INFO -  = Minimal loss value = -5.6491804122924805,
#  - 31 steps took 4.8 seconds, avg_step_time=0.155
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 77
# static_classes.trainer - INFO -  = Minimal loss value = -5.6491804122924805,
#  - 31 steps took 4.7 seconds, avg_step_time=0.152
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 78
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.7 seconds, avg_step_time=0.150
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 79
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.5 seconds, avg_step_time=0.147
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 80
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.6 seconds, avg_step_time=0.150
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 81
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.6 seconds, avg_step_time=0.149
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 82
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.6 seconds, avg_step_time=0.149
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 83
# static_classes.trainer - INFO -  = Minimal loss value = -5.74231481552124,
#  - 31 steps took 4.5 seconds, avg_step_time=0.144
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 84
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.7 seconds, avg_step_time=0.152
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 85
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.7 seconds, avg_step_time=0.150
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 86
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.5 seconds, avg_step_time=0.146
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 87
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.5 seconds, avg_step_time=0.146
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 88
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 89
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.5 seconds, avg_step_time=0.145
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 90
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 91
# static_classes.trainer - DEBUG - drop lr: 2.9999999242136255e-05
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 92
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.6 seconds, avg_step_time=0.148
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 93
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.6 seconds, avg_step_time=0.148
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 94
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.5 seconds, avg_step_time=0.147
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 95
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 96
# static_classes.trainer - INFO -  = Minimal loss value = -5.9184465408325195,
#  - 31 steps took 4.7 seconds, avg_step_time=0.151
#  - test time: 0.9 seconds
# static_classes.trainer - INFO -
# Epoch: 97
# static_classes.trainer - INFO -  = Minimal loss value = -6.054978370666504,
#  - 31 steps took 4.6 seconds, avg_step_time=0.150
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 98
# static_classes.trainer - INFO -  = Minimal loss value = -6.054978370666504,
#  - 31 steps took 4.8 seconds, avg_step_time=0.156
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 99
# static_classes.trainer - INFO -  = Minimal loss value = -6.054978370666504,
#  - 31 steps took 4.6 seconds, avg_step_time=0.147
#  - test time: 0.8 seconds
# static_classes.trainer - INFO -
# Epoch: 100
# static_classes.trainer - INFO -  = Minimal loss value = -6.054978370666504,
#  - 31 steps took 4.5 seconds, avg_step_time=0.145
#  - test time: 0.8 seconds
# tensorflow - INFO - Restoring parameters from /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/models/0.1/SIR/checkpoints/best_ckpt_2989
# static_classes.model - INFO - Model's frozen graph saved in /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/models/0.1/SIR
# static_classes.model - INFO - Model's graph keys saved at /Users/ivan/Developer/git/deep-abstractions/tool_migration/stochnetv2/SIR/models/0.1/SIR/graph_keys.json

# %% [markdown]
# ### Inference

# %%
checkpoint = ""
with open("best_ckpt.txt", "r") as f:
    checkpoint = f.readline()

nn = StochNet(
    nb_past_timesteps=1,
    nb_features=3,
    nb_randomized_params=len(params),
    project_folder=project_folder,
    timestep=timestep,
    dataset_id=dataset_id,
    model_id=model_id,
    mode="inference",
)

# n_settings = 9
traj_per_setting = 10
n_steps = 10

settings = te_gen.get_merged_concentrations_and_params()
setting_idx = 0
curr_state = settings[setting_idx : setting_idx + 1, np.newaxis, :]

next_state_samples = nn.next_state(
    curr_state_values=curr_state,
    curr_state_rescaled=False,
    scale_back_result=True,
    round_result=False,
    n_samples=10000,
)

# print(next_state_samples.shape)
# first_sample = next_state_samples[0]
# first_setting = first_sample[0]
# print(first_setting)

nn_traces = nn.generate_traces(
    settings[:, np.newaxis, :],
    n_steps=n_steps,
    n_traces=traj_per_setting,
    curr_state_rescaled=False,
    scale_back_result=True,
    round_result=True,
    add_timestamps=True,
)

# np.save("nn_traces.npy", nn_traces)
# Out:
# static_classes.model - INFO - Model created in inference mode.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.81it/s]

# %%
print(te_dataset.shape)
print(nn_traces.shape)
# Out:
# (1000, 11, 6)
# (100, 10, 11, 4)

# %%
# get the first initial setting, the first simulation
print(nn_traces[0][0])
# Out:
# [[  0.   73.  131.  125. ]
#  [  0.1  71.  192.   72. ]
#  [  0.2  44.  258.   47. ]
#  [  0.3  21.  300.   40. ]
#  [  0.4  11.  303.   31. ]
#  [  0.5   5.  311.   30. ]
#  [  0.6   4.  316.   29. ]
#  [  0.7   1.  318.   27. ]
#  [  0.8   1.  321.   27. ]
#  [  0.9   2.  321.   27. ]
#  [  1.    0.  325.   29. ]]
